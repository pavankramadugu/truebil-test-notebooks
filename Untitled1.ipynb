# %%
import redis
import pickle

# %%
r = redis.StrictRedis(host='localhost', port=6360, db=0)

# %%
p = pickle.loads(r.get('cluster_benchmark_data'))

# %%
p
# Out:
# {1: [cluster 0, 100000, 700001, 9223372036854775807
#   metric                                   count      mean       std
#   0                                         31.0  6.935484  5.841650
#   1                                         32.0  9.468750  8.230980
#   2                                         30.0  9.000000  6.942622
#   3                                         26.0  9.153846  6.596574
#   4                                         21.0  9.571428  6.425925
#   5                                         17.0  9.176471  7.366341
#   6                                         11.0  5.909091  3.654500,
#   cluster 100001, 300000, Hatchback, Liftback, Petrol, 0, 3
#   metric                                              count       mean       std
#   0                                                    20.0   7.650000  4.464023
#   1                                                    20.0  11.350000  6.043798
# ...

# %%
p[5][cluster == '0, 100000, 700001, 9223372036854775807, Hatchback, Liftback, Petrol']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-16c09f28760a> in <module>
# ----> 1 p[5][cluster == '0, 100000, 700001, 9223372036854775807, Hatchback, Liftback, Petrol']
#
# NameError: name 'cluster' is not defined
